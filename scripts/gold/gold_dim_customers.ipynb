# %%
query="""
SELECT 
  customer_id,
  customer_city AS city,
  customer_state AS state,
  customer_zip_code_prefix AS zip_code
FROM workspace.ecommerce_silver.df_customers
"""
df=spark.sql(query)

# %%
display(df.limit(5))

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.ecommerce_gold.dim_customers")
