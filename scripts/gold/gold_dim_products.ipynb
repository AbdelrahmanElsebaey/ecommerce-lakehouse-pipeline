# %%
query="""
    SELECT 
        p.product_id,
        p.product_category_name AS category_name,
        p.product_weight_g AS weight_g,
        p.product_length_cm AS length_cm,
        p.product_height_cm AS height_cm,
        p.product_width_cm AS width_cm,
        p.product_volume_cm3 AS volume_cm3,
        p.density_g_per_cm3 AS density_g_per_cm3
    FROM workspace.ecommerce_silver.df_products p
    """

df=spark.sql(query)

# %%
display(df.limit(5))

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.ecommerce_gold.dim_products")
