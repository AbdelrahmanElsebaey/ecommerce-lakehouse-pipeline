# %%
query="""
SELECT 
  user_id,
  name,
  email AS email_address,
  phone AS phone_number,
  website,
  source AS data_source
FROM workspace.ecommerce_silver.api_users
"""
df=spark.sql(query)

# %%
display(df.limit(5))

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.ecommerce_gold.dim_users")
