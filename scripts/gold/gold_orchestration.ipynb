# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)
logger = logging.getLogger(__name__)

notebooks = [
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/gold/gold_dim_customers",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/gold/gold_dim_date",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/gold/gold_dim_products",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/gold/gold_dim_users",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/gold/gold_fact_orders"
]

for nb in notebooks:
    notebook_name = nb.split("/")[-1]
    try:
        logger.info(f"Starting: {notebook_name}")
        dbutils.notebook.run(nb, timeout_seconds=600)
        logger.info(f"Success: {notebook_name}")
    except Exception as e:
        logger.error(f"Failed: {notebook_name} → {e}")
        raise
