# %% [markdown]
# ##USE CATALOG

# %%
# %sql
USE CATALOG workspace

# %% [markdown]
# ##CREATE SCHEMAS

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce_bronze
COMMENT 'BRONZE LAYER : raw data' ;

CREATE SCHEMA IF NOT EXISTS ecommerce_silver
COMMENT 'SILVER LAYER : cleaned/transformed data' ;

CREATE SCHEMA IF NOT EXISTS ecommerce_gold
COMMENT 'GOLD LAYER : business-ready data' ;

# %% [markdown]
# ##CREATE VOLUME

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.ecommerce_bronze.raw_sources
COMMENT 'Raw data sources' ;
