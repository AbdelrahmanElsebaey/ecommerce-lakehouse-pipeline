# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)
logger = logging.getLogger(__name__)

notebooks = [
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_categories_api",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_users_api",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_products_api",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_customers_csv",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_orders_csv",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_orderitems_csv",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_products_csv",
    "/Workspace/Users/a.elrahman2005@gmail.com/ecommerce_lakehouse_pipeline/scripts/silver/silver_payments_csv"
]

for nb in notebooks:
    notebook_name = nb.split("/")[-1] #to grab the last item
    try:
        logger.info(f"Starting: {notebook_name}")
        dbutils.notebook.run(nb, timeout_seconds=300)
        logger.info(f"Success: {notebook_name}")
    except Exception as e:
        logger.error(f"Failed: {notebook_name} → {e}")
        raise
